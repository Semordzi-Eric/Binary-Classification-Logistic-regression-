# %%
# Machine Learning Dataset
'''
This dataset simulates the productivity of AI developers over 500 days, capturing the subtle 
interaction between deep work, distractions, caffeine intake, and code quality. Designed to 
push the limits of machine learning, this data blends behavioral, physiological, and productivity
indicators to allow for advanced predictive modeling, regression, clustering, and time-series analysis.

'''

'''
Binary classification (task_success)
Regression (e.g., predicting cognitive_load)
Clustering of work patterns
Correlation analysis & feature importance
Time series simulation & rolling averages (useful with synthetic date column)
Exploratory Data Analysis (EDA)
'''
# Out:
# '\nBinary classification (task_success)\nRegression (e.g., predicting cognitive_load)\nClustering of work patterns\nCorrelation analysis & feature importance\nTime series simulation & rolling averages (useful with synthetic date column)\nExploratory Data Analysis (EDA)\n'

# %%
'''
 Inspiration
How does caffeine impact bugs in code?
Can you predict if a dev will succeed today based on distractions and AI tool use?
What’s the optimal balance between AI usage and raw coding time?

'''
# Out:
# '\n Inspiration\nHow does caffeine impact bugs in code?\nCan you predict if a dev will succeed today based on distractions and AI tool use?\nWhat’s the optimal balance between AI usage and raw coding time?\n\n'

# %%
'''
hours_coding	:Total focused hours spent on software development work (0–12 hours).
coffee_intake_mg:	Daily caffeine intake in milligrams (0–600 mg).
distractions	: Number of distractions (e.g., meetings, Slack notifications) (0–10).
sleep_hours     :	Number of hours of sleep the previous night (3–10 hours).
commits	        : Number of code commits pushed during the day (0–20).
bugs_reported   : Number of bugs reported in code written that day (0–10).
ai_usage_hours  : Number of hours spent using AI tools (e.g., ChatGPT, Copilot) (0–12).
cognitive_load	: Self-reported mental strain on a scale of 1 to 10.
task_success	: Target column — whether the daily productivity goal was achieved (0/1).
'''
# Out:
# '\nhours_coding\t:Total focused hours spent on software development work (0–12 hours).\ncoffee_intake_mg:\tDaily caffeine intake in milligrams (0–600 mg).\ndistractions\t: Number of distractions (e.g., meetings, Slack notifications) (0–10).\nsleep_hours     :\tNumber of hours of sleep the previous night (3–10 hours).\ncommits\t        : Number of code commits pushed during the day (0–20).\nbugs_reported   : Number of bugs reported in code written that day (0–10).\nai_usage_hours  : Number of hours spent using AI tools (e.g., ChatGPT, Copilot) (0–12).\ncognitive_load\t: Self-reported mental strain on a scale of 1 to 10.\ntask_success\t: Target column — whether the daily productivity goal was achieved (0/1).\n'

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv("C:/Users/DELL/Downloads/Data/AI Data/ai_dev_productivity.csv")
df.head()
# Out:
#    hours_coding  coffee_intake_mg  distractions  sleep_hours  commits  \
# 0          5.99               600             1          5.8        2
# 1          4.72               568             2          6.9        5
# 2          6.30               560             1          8.9        2
# 3          8.05               600             7          6.3        9
# 4          4.53               421             6          6.9        4
#
#    bugs_reported  ai_usage_hours  cognitive_load  task_success
# 0              1            0.71             5.4             1
# 1              3            1.75             4.7             1
# 2              0            2.27             2.2             1
# 3              5            1.40             5.9             0
# 4              0            1.26             6.3             1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   hours_coding      500 non-null    float64
#  1   coffee_intake_mg  500 non-null    int64
#  2   distractions      500 non-null    int64
#  3   sleep_hours       500 non-null    float64
#  4   commits           500 non-null    int64
#  5   bugs_reported     500 non-null    int64
#  6   ai_usage_hours    500 non-null    float64
#  7   cognitive_load    500 non-null    float64
#  8   task_success      500 non-null    int64
# dtypes: float64(4), int64(5)
# memory usage: 35.3 KB

# %%
df.describe().T
# Out:
#                   count       mean         std  min       25%     50%  \
# hours_coding      500.0    5.01560    1.947253  0.0    3.6000    5.03
# coffee_intake_mg  500.0  463.19200  142.334991  6.0  369.5000  500.50
# distractions      500.0    2.97600    1.678409  0.0    2.0000    3.00
# sleep_hours       500.0    6.97580    1.455965  3.0    6.1000    6.95
# commits           500.0    4.60800    2.704990  0.0    3.0000    5.00
# bugs_reported     500.0    0.85800    1.102846  0.0    0.0000    0.00
# ai_usage_hours    500.0    1.51092    1.085557  0.0    0.6975    1.26
# cognitive_load    500.0    4.49820    1.868861  1.0    3.1750    4.40
# task_success      500.0    0.60600    0.489124  0.0    0.0000    1.00
#
#                       75%     max
# hours_coding        6.275   12.00
# coffee_intake_mg  600.000  600.00
# distractions        4.000    8.00
# sleep_hours         7.900   10.00
# commits             6.000   13.00
# bugs_reported       2.000    5.00
# ...

# %%
part_df = df.drop(['coffee_intake_mg', 'task_success'], axis=1)
part_2df = df[['coffee_intake_mg', 'task_success']]

# %%
for col in df.columns:
    plt.Figure(figsize=(5,15))
    sns.histplot(df[col],  kde=True, bins = 30)
    plt.title(f'Histogram plot of {col}')
    plt.xlabel(col)
    plt.ylabel('Frequency')
    plt.tight_layout()
    plt.show()

# %%
# Melt the DataFrame to long-form for seaborn
df_melted = part_df.melt(var_name='Column', value_name='Value')

# Plot all box plots on the same figure
plt.figure(figsize=(12, 8))
sns.boxplot(x='Column', y='Value', data=df_melted)

sns.despine(offset=10, trim=True)
plt.title('Box Plots of All Columns')
plt.xlabel('Column')
plt.ylabel('Value')
plt.tight_layout()
plt.show()

# %%
sns.pairplot(df)
plt.show()

# %%
df.describe().T
# Out:
#                   count       mean         std  min       25%     50%  \
# hours_coding      500.0    5.01560    1.947253  0.0    3.6000    5.03
# coffee_intake_mg  500.0  463.19200  142.334991  6.0  369.5000  500.50
# distractions      500.0    2.97600    1.678409  0.0    2.0000    3.00
# sleep_hours       500.0    6.97580    1.455965  3.0    6.1000    6.95
# commits           500.0    4.60800    2.704990  0.0    3.0000    5.00
# bugs_reported     500.0    0.85800    1.102846  0.0    0.0000    0.00
# ai_usage_hours    500.0    1.51092    1.085557  0.0    0.6975    1.26
# cognitive_load    500.0    4.49820    1.868861  1.0    3.1750    4.40
# task_success      500.0    0.60600    0.489124  0.0    0.0000    1.00
#
#                       75%     max
# hours_coding        6.275   12.00
# coffee_intake_mg  600.000  600.00
# distractions        4.000    8.00
# sleep_hours         7.900   10.00
# commits             6.000   13.00
# bugs_reported       2.000    5.00
# ...

# %%
part_2df.head()
# Out:
#    coffee_intake_mg  task_success
# 0               600             1
# 1               568             1
# 2               560             1
# 3               600             0
# 4               421             1

# %%
sns.boxplot(y=df['coffee_intake_mg'])

plt.title('Coffee Intake')
plt.ylabel('Values')
plt.show()

# %%
sns.violinplot(y=df['task_success'])

plt.title('Task Success')
plt.ylabel('Values')
plt.show()

# %%
# Melt into long format
df_melted = part_df.melt(var_name='Column', value_name='Value')

# Violin plot of all columns on the same figure
plt.figure(figsize=(12, 8))
sns.violinplot(x='Column', y='Value', data=df_melted)

sns.despine(offset=10, trim=True)
plt.title('Violin Plots of All Columns')
plt.xlabel('Column')
plt.ylabel('Value')
plt.tight_layout()
plt.show()

# %%
# Create a figure with subplots (1 row, n columns)
fig, axes = plt.subplots(1, len(part_df.columns), figsize=(5 * len(part_df.columns), 12), sharey=True)

for i, col in enumerate(part_df.columns):
    sns.violinplot(y=part_df[col], ax=axes[i], color='skyblue')
    axes[i].set_title(f'Violin Plot of {col}')
    axes[i].set_xlabel('')
    axes[i].set_ylabel('Value' if i == 0 else '')
    sns.despine(ax=axes[i], offset=10, trim=True)

plt.tight_layout()
plt.show()

# %%
corr = df.corr()
plt.figure(figsize=(12,8))
sns.heatmap(corr, annot=True, fmt = '.2f', cmap = 'coolwarm')
plt.title('Heatmap For Data Correlation')
plt.show()

# %%
# From the Above histplot, we pick columns that have some correlation with outcome variable task 

model_var = df[['hours_coding', 'coffee_intake_mg', 'sleep_hours', 'commits', 'ai_usage_hours']]
model_var.head(2)
# Out:
#    hours_coding  coffee_intake_mg  sleep_hours  commits  ai_usage_hours
# 0          5.99               600          5.8        2            0.71
# 1          4.72               568          6.9        5            1.75

# %%
 # WE FIRST MODEL USING A BINARY CLASSIFICATION MODEL,  LOGISTICS REGRESSION SPECIFICALLY AND SEE HOW OUR MODEL PERFORMS
# WE FIRST SCALE THE FEATURE TO MAKE SURE EVERY COLUMN CONTRIBUTE APPROPRIATELY

from sklearn.preprocessing import StandardScaler

features = model_var

scaler = StandardScaler()
scaled_features = scaler.fit_transform(features)


from sklearn.decomposition import PCA
# Step 3: Apply PCA (optional: retain 95% variance or choose a fixed number of components)
pca = PCA(n_components=0.95)  # or use n_components=3, etc.
X_pca = pca.fit_transform(scaled_features)

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix, classification_report

X= X_pca
Y = df['task_success']

X_train, X_test, Y_train,Y_test = train_test_split(X,Y, test_size=0.2, random_state=42)

# %%
model = LogisticRegression()
model.fit(X_train, Y_train)

Y_pred = model.predict(X_test)

print(classification_report(Y_test, Y_pred))
conf_mat = confusion_matrix(Y_test , Y_pred)
sns.heatmap(conf_mat, annot=True, fmt = '.2f', cmap = 'coolwarm')
# Out:
#               precision    recall  f1-score   support
#
#            0       0.77      0.79      0.78        34
#            1       0.89      0.88      0.89        66
#
#     accuracy                           0.85       100
#    macro avg       0.83      0.84      0.83       100
# weighted avg       0.85      0.85      0.85       100
# <Axes: >

# %%
# CHECKING FOR OVERFITTING
from sklearn.model_selection import cross_val_score
scores = cross_val_score(model, scaled_features, Y, cv=5)
print("CV Accuracy:", scores)
print("Mean CV Accuracy:", scores.mean())

# The scores suggest no overfitting
# Out:
# CV Accuracy: [0.85 0.86 0.84 0.84 0.85]
# Mean CV Accuracy: 0.8479999999999999

# %%
# CHECKING FOR MULTICOLLINEARITY
from statsmodels.stats.outliers_influence import variance_inflation_factor
# If X is a NumPy array, convert it like this
feature_names = ['hours_coding', 'coffee_intake_mg', 'sleep_hours', 'commits', 'ai_usage_hours']
X_df = pd.DataFrame(X, columns=feature_names)

# Calculate VIF
vif_data = pd.DataFrame()
vif_data["Feature"] = X_df.columns
vif_data["VIF"] = [variance_inflation_factor(X_df.values, i) for i in range(X_df.shape[1])]

print(vif_data)

# The result below shows high multicollinearity scores for hours coding ad coffee intake, which a also significant features of our predictor variables
# So we look forward for a better solution
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[56], line 5
#       3 # If X is a NumPy array, convert it like this
#       4 feature_names = ['hours_coding', 'coffee_intake_mg', 'sleep_hours', 'commits', 'ai_usage_hours']
# ----> 5 X_df = pd.DataFrame(X, columns=feature_names)
#       7 # Calculate VIF
#       8 vif_data = pd.DataFrame()
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\frame.py:827, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     816         mgr = dict_to_mgr(
#     817             # error: Item "ndarray" of "Union[ndarray, Series, Index]" has no
#     818             # attribute "name"
#    (...)
#     824             copy=_copy,
#     825         )
#     826     else:
# --> 827         mgr = ndarray_to_mgr(
#     828             data,
#     829             index,
#     830             columns,
# ...

# %%
####################  REPORT #########
###### CLASSIFICATION REPORT
####ACCURACY
# This explains how many of the programmers evaluated did the model correctly identify as either completed a task or not
# THe model was correct 85% of the time
#### PRECISION(Trust in predictions)
# This explains how correct the model actually is when it makes a prediction
# 90% of the time,the model makes the right predictions programmers task completion and 76% otherwise






#########   CONFUSION MATRIX
# Correct and incorrect predictions
## TASK COMPLETION
# Out of the 100 customers, 28 predicted to stay actually stayed, and 45 predicted to stay actually left
## LEFT
# 67 predicted to leave actually left and 326 predicted to leave actually stayed

# %%
corr = model_var.corr()
plt.figure(figsize=(10,6))
sns.heatmap(corr, annot=True, fmt = '.2f', cmap = 'coolwarm')
plt.title('Heatmap For Data Correlation')
plt.show()

# %%
df.columns.tolist()
# Out:
# ['hours_coding',
#  'coffee_intake_mg',
#  'distractions',
#  'sleep_hours',
#  'commits',
#  'bugs_reported',
#  'ai_usage_hours',
#  'cognitive_load',
#  'task_success']

# %%
# REGRESSION ANALYSIS
# MODELING CODING HOURS

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

x = df[['coffee_intake_mg', 'commits',  'ai_usage_hours']]
y = df['hours_coding']

x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.2)
lin_model = LinearRegression()
lin_model.fit(x_train, y_train)
lin_model.score(x_test,y_test)
# Out:
# 0.8839955985113523

# %%
# using statmodels
import statsmodels.api as sm
X = sm.add_constant(x)
sm_model = sm.OLS(y,X).fit()
sm_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:           hours_coding   R-squared:                       0.847
# Model:                            OLS   Adj. R-squared:                  0.846
# Method:                 Least Squares   F-statistic:                     916.0
# Date:                Fri, 06 Jun 2025   Prob (F-statistic):          8.89e-202
# Time:                        12:56:44   Log-Likelihood:                -572.69
# No. Observations:                 500   AIC:                             1153.
# Df Residuals:                     496   BIC:                             1170.
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# ...

# %%
# checking for model validity
# RESIDUAL ANALYSIS
import scipy.stats as stats

y_pred = lin_model.predict(x_test)
residuals= y_pred - y_test
sns.histplot(residuals, kde=True)
plt.show()

# %%
# shakira wilt rest for normality
shapiro = stats.shapiro(residuals)
print(shapiro)
# Out:
# ShapiroResult(statistic=np.float64(0.9737200900633081), pvalue=np.float64(0.042861450324254535))

# %%
# CHECKING FOR MULTICOLLINEARITY
from statsmodels.stats.outliers_influence import variance_inflation_factor
vif_data = pd.DataFrame()
vif_data['Feature'] = x_train.columns
vif_data['VIF']=[variance_inflation_factor(x_train, i) for i in range(x_train.shape[1])]
print(vif_data)
'''How to Interpret VIF Values:
VIF < 5 → No serious multicollinearity ✅
VIF 5-10 → Moderate multicollinearity ⚠️
VIF > 10 → Severe multicollinearity ❌ (Consider removing/reducing variables)
How to fix it?
Remove one of the correlated variables
Combine them into one feature (e.g., total study time = study hours + library time)
Use Ridge or Lasso Regression to reduce multicollinearity effects'''
# Out:
#             Feature       VIF
# 0  coffee_intake_mg  7.379584
# 1           commits  5.656657
# 2    ai_usage_hours  3.722535
# 'How to Interpret VIF Values:\nVIF < 5 → No serious multicollinearity ✅\nVIF 5-10 → Moderate multicollinearity ⚠️\nVIF > 10 → Severe multicollinearity ❌ (Consider removing/reducing variables)\nHow to fix it?\nRemove one of the correlated variables\nCombine them into one feature (e.g., total study time = study hours + library time)\nUse Ridge or Lasso Regression to reduce multicollinearity effects'

# %%
corr = x.corr()
plt.figure(figsize=(10,5))
sns.heatmap(corr, annot=True, fmt = '.2f', cmap = 'coolwarm')
plt.title('Heatmap For Data Correlation')
plt.show()

# %%
# THE ABOVE PLOT MAY EXPLAIN THE SEVERITY OF THE MULICOLLINEARITY VALUES RECORDED
